# %% [markdown]
# # Chemprop

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnchoredText

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.decomposition import PCA
from pymatgen.core import Molecule
from rdkit.Chem import rdChemReactions
from rdkit import Chem
from rdkit import RDLogger
from tqdm import tqdm

import openbabel as ob

ob_log_handler = ob.OBMessageHandler()
ob_log_handler.SetOutputLevel(0)
RDLogger.DisableLog("rdApp.*")

from qtaim_embed.utils.translation import translate_qm8, translate_qm9
# Out:
# /home/santiagovargas/anaconda3/envs/qtaim_embed/lib/python3.11/site-packages/openbabel/__init__.py:14: UserWarning: "import openbabel" is deprecated, instead use "from openbabel import openbabel"
#   warnings.warn('"import openbabel" is deprecated, instead use "from openbabel import openbabel"')

# %%
file_train = "../../../data/splits_1205/train_qm8_qtaim_1205_labelled.pkl"
file_test = "../../../data/splits_1205/test_qm8_qtaim_1205_labelled.pkl"
train_df = pd.read_pickle(file_train)
test_df = pd.read_pickle(file_test)

file_train = "../../../data/splits_1205/train_qm9_qtaim_1205_labelled.pkl"
file_test = "../../../data/splits_1205/test_qm9_qtaim_1205_labelled.pkl"
train_df_qm9 = pd.read_pickle(file_train)
test_df_qm9 = pd.read_pickle(file_test)

# %%
# atom qtaim keys
atom_qtaim_keys = [
    "extra_feat_atom_Hamiltonian_K",
    "extra_feat_atom_e_density",
    "extra_feat_atom_lap_e_density",
    "extra_feat_atom_ave_loc_ion_E",
    "extra_feat_atom_esp_e",
    "extra_feat_atom_esp_total",
    "extra_feat_atom_ellip_e_dens",
    "extra_feat_atom_energy_density",
]

# %%
file_train_100 = "../../../data/splits_1205/train_qm8_qtaim_1205_labelled_100.pkl"
file_train_1000 = "../../../data/splits_1205/train_qm8_qtaim_1205_labelled_1000.pkl"
file_train_10000 = "../../../data/splits_1205/train_qm8_qtaim_1205_labelled_10000.pkl"
train_qm8_100 = pd.read_pickle(file_train_100)
train_qm8_1000 = pd.read_pickle(file_train_1000)
train_qm8_10000 = pd.read_pickle(file_train_10000)

file_train_qm9_100 = "../../../data/splits_1205/train_qm9_qtaim_1205_labelled_100.pkl"
file_train_qm9_1000 = "../../../data/splits_1205/train_qm9_qtaim_1205_labelled_1000.pkl"
file_train_qm9_10000 = (
    "../../../data/splits_1205/train_qm9_qtaim_1205_labelled_10000.pkl"
)
file_train_qm9_100000 = (
    "../../../data/splits_1205/train_qm9_qtaim_1205_labelled_100000.pkl"
)
train_qm9_100 = pd.read_pickle(file_train_qm9_100)
train_qm9_1000 = pd.read_pickle(file_train_qm9_1000)
train_qm9_10000 = pd.read_pickle(file_train_qm9_10000)
train_qm9_100000 = pd.read_pickle(file_train_qm9_100000)

# %%
translate_qm9(
    train_df_qm9,
    "./benchmark_data/qm9_train_qtaim.csv",
    "./benchmark_data/qm9_train_qtaim_feats.pkl",
    extra_feats=atom_qtaim_keys,
)
# Out:
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
#
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
#
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
#
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
#
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
# ...

# %%
translate_qm9(
    test_df_qm9,
    "./benchmark_data/qm9_test_qtaim.csv",
    "./benchmark_data/qm9_test_qtaim_feats.pkl",
    extra_feats=atom_qtaim_keys,
)
# Out:
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
#
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
#
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
# ...

# %%
translate_qm8(
    train_df,
    "./benchmark_data/qm8_train_qtaim.csv",
    "./benchmark_data/qm8_train_qtaim_feats.pkl",
    extra_feats=atom_qtaim_keys,
)
# Out:
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
#
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
#
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
# ...

# %%
translate_qm8(
    test_df,
    "./benchmark_data/qm8_test_qtaim.csv",
    "./benchmark_data/qm8_test_qtaim_feats.pkl",
    extra_feats=atom_qtaim_keys,
)
# Out:
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
#
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
#
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Warning  in PerceiveBondOrders
# ...

# %%
translate_qm9(
    train_qm9_100,
    "./benchmark_data/qm9_train_100_qtaim.csv",
    "./benchmark_data/qm9_train_100_qtaim_feats.pkl",
    extra_feats=atom_qtaim_keys,
)

translate_qm9(
    train_qm9_1000,
    "./benchmark_data/qm9_train_1000_qtaim.csv",
    "./benchmark_data/qm9_train_1000_qtaim_feats.pkl",
    extra_feats=atom_qtaim_keys,
)

translate_qm9(
    train_qm9_10000,
    "./benchmark_data/qm9_train_10000_qtaim.csv",
    "./benchmark_data/qm9_train_10000_qtaim_feats.pkl",
    extra_feats=atom_qtaim_keys,
)

translate_qm9(
    train_qm9_100000,
    "./benchmark_data/qm9_train_100000_qtaim.csv",
    "./benchmark_data/qm9_train_100000_qtaim_feats.pkl",
    extra_feats=atom_qtaim_keys,
)
# Out:
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# .... > writing csv
# ...
# 100%|██████████| 97/97 [00:00<00:00, 188355.32it/s]
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
#
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
#
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
# ...

# %%
translate_qm8(
    train_qm8_100,
    "./benchmark_data/qm8_train_100_qtaim.csv",
    "./benchmark_data/qm8_train_100_qtaim_feats.pkl",
    extra_feats=atom_qtaim_keys,
)

translate_qm8(
    train_qm8_1000,
    "./benchmark_data/qm8_train_1000_qtaim.csv",
    "./benchmark_data/qm8_train_1000_qtaim_feats.pkl",
    extra_feats=atom_qtaim_keys,
)

translate_qm8(
    train_qm8_10000,
    "./benchmark_data/qm8_train_10000_qtaim.csv",
    "./benchmark_data/qm8_train_10000_qtaim_feats.pkl",
    extra_feats=atom_qtaim_keys,
)
# Out:
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# .... > writing csv
# ...
# 100%|██████████| 97/97 [00:00<00:00, 170157.88it/s]
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders
#
# ...
# *** Open Babel Error  in TetStereoToWedgeHash
# ...

# %% [markdown]
# # Dimenet

# %%
from qtaim_embed.utils.translation import (
    get_molecule_translation_dimenet_qm8,
    get_molecule_translation_dimenet_qm9,
)

# %%
get_molecule_translation_dimenet_qm8(train_df, "./qm8_train_dimenet_small.npz")
get_molecule_translation_dimenet_qm8(test_df, "./qm8_test_dimenet_large.npz")
# Out:
# 2061
# 1927

# %%
get_molecule_translation_dimenet_qm9(train_df_qm9, "./qm9_train_dimenet_small.npz")
get_molecule_translation_dimenet_qm9(test_df_qm9, "./qm9_test_dimenet_large.npz")
# Out:
# 3921
# 12987
