# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error

# %%
# No QTAIM

# %%
chemprop_qm9_preds = "../benchmark_data/qm9_chemprop_no_qtaim/test_preds_qm9.csv"
chemprop_qm8_preds = "../benchmark_data/qm8_chemprop_no_qtaim/test_preds_qm8.csv"
test_qm9 = "../benchmark_data/qm9_test_chemprop.csv"
test_qm8 = "../benchmark_data/qm8_test_chemprop.csv"
df_qm8_chemprop = pd.read_csv(chemprop_qm8_preds)
df_qm9_chemprop = pd.read_csv(chemprop_qm9_preds)
df_qm8 = pd.read_csv(test_qm8)
df_qm9 = pd.read_csv(test_qm9)

# %%
qm8_targets = ["CC2_E1", "CC2_E2"]
qm9_targets = ["homo", "lumo", "gap", "U0"]

df_qm8 = df_qm8[qm8_targets]
df_qm8_chemprop = df_qm8_chemprop[qm8_targets]

df_qm9 = df_qm9[qm9_targets]
df_qm9_chemprop = df_qm9_chemprop[qm9_targets]

# %%
# compute mae for each
mae_dict = {}
r2_dict = {}
for key in qm8_targets:
    mae_dict[key] = mean_absolute_error(df_qm8[key], df_qm8_chemprop[key])
    # compute r2
    r2_dict[key] = r2_score(df_qm8[key], df_qm8_chemprop[key])

# %%
print(r2_dict)
print(mae_dict)
# Out:
# {'CC2_E1': -0.0490938914144432, 'CC2_E2': -0.033068179304211354}
# {'CC2_E1': 0.037292939428446296, 'CC2_E2': 0.02692865299754383}

# %%
# compute mae for each
mae_dict = {}
r2_dict = {}
for key in qm9_targets:
    mae_dict[key] = mean_absolute_error(df_qm9[key], df_qm9_chemprop[key])
    # compute r2
    r2_dict[key] = r2_score(df_qm9[key], df_qm9_chemprop[key])

# %%
print(r2_dict)
print(mae_dict)
# Out:
# {'homo': 0.9677056506309262, 'lumo': 0.9913884339350556, 'gap': 0.9859296058412854, 'U0': 0.9907029221316962}
# {'homo': 0.0027692202740849862, 'lumo': 0.003111041740738191, 'gap': 0.0038223465479134537, 'U0': 1.655494097427923}

# %%
import matplotlib.pyplot as plt
import seaborn as sns

name_list = ["homo", "lumo", "gap", "U0"]
df_qm9[key]
fig, ax = plt.subplots(1, 4, figsize=(15, 5))
for i in range(4):
    key = name_list[i]
    sns.scatterplot(x=df_qm9[key], y=df_qm9_chemprop[key], ax=ax[i])
    ax[i].set_title(
        "{} (MAE: {:.5f}, $R^2$: {:.3f})".format(
            key,
            mae_dict[key],
            r2_dict[key],
        )
    )
    ax[i].set_xlabel("Predicted")
    ax[i].set_ylabel("True")
    # ax[i].set_xlim(-10, 10)
    # ax[i].set_ylim(-10, 10)
    # ax[i].plot([-10, 10], [-10, 10], color="black", linestyle="--")

fig.suptitle("Best Performance Chemprop(No QTAIM) QM9 ")
fig.tight_layout()

# %%
# QTAIM

# %%
chemprop_qm9_preds = "../benchmark_data/qm9_chemprop_qtaim/test_preds_qm9.csv"
chemprop_qm8_preds = "../benchmark_data/qm8_chemprop_qtaim/test_preds_qm8_base.csv"
test_qm9 = "../benchmark_data/qm9_test_chemprop.csv"
test_qm8 = "../benchmark_data/qm8_test_chemprop.csv"
df_qm8_chemprop = pd.read_csv(chemprop_qm8_preds)
df_qm9_chemprop = pd.read_csv(chemprop_qm9_preds)
df_qm8 = pd.read_csv(test_qm8)
df_qm9 = pd.read_csv(test_qm9)

qm8_targets = ["CC2_E1", "CC2_E2"]
qm9_targets = ["homo", "lumo", "gap", "U0"]

df_qm8 = df_qm8[qm8_targets]
df_qm8_chemprop = df_qm8_chemprop[qm8_targets]

df_qm9 = df_qm9[qm9_targets]
df_qm9_chemprop = df_qm9_chemprop[qm9_targets]

# %%
# compute mae for each
mae_dict = {}
r2_dict = {}
for key in qm8_targets:
    mae_dict[key] = mean_absolute_error(df_qm8[key], df_qm8_chemprop[key])
    # compute r2
    r2_dict[key] = r2_score(df_qm8[key], df_qm8_chemprop[key])

print(r2_dict)
print(mae_dict)
# Out:
# {'CC2_E1': 0.9703904742615372, 'CC2_E2': 0.9373021273975618}
# {'CC2_E1': 0.005234751074468324, 'CC2_E2': 0.0060418002346398466}

# %%
# compute mae for each
mae_dict = {}
r2_dict = {}
for key in qm9_targets:
    mae_dict[key] = mean_absolute_error(df_qm9[key], df_qm9_chemprop[key])
    # compute r2
    r2_dict[key] = r2_score(df_qm9[key], df_qm9_chemprop[key])

print(mae_dict)
print(r2_dict)
import matplotlib.pyplot as plt
import seaborn as sns

name_list = ["homo", "lumo", "gap", "U0"]
df_qm9[key]
fig, ax = plt.subplots(1, 4, figsize=(15, 5))
for i in range(4):
    key = name_list[i]
    sns.scatterplot(x=df_qm9[key], y=df_qm9_chemprop[key], ax=ax[i])
    ax[i].set_title(
        "{} (MAE: {:.5f}, $R^2$: {:.3f})".format(
            key,
            mae_dict[key],
            r2_dict[key],
        )
    )
    ax[i].set_xlabel("Predicted")
    ax[i].set_ylabel("True")
    # ax[i].set_xlim(-10, 10)
    # ax[i].set_ylim(-10, 10)
    # ax[i].plot([-10, 10], [-10, 10], color="black", linestyle="--")

fig.suptitle("Best Performance Chemprop(QTAIM) QM9 ")
fig.tight_layout()
# Out:
# {'homo': 0.0030052467910050232, 'lumo': 0.003448907182444475, 'gap': 0.004213777081319067, 'U0': 1.3710287461084236}
# {'homo': 0.9619360397388279, 'lumo': 0.9892091569213962, 'gap': 0.9829383869770403, 'U0': 0.9954721338324276}

# %%
# no qtaim
# r2
r2_no_qtaim = {
    "homo": 0.9677056506309262,
    "lumo": 0.9913884339350556,
    "gap": 0.9859296058412854,
    "U0": 0.9907029221316962,
}
print(np.mean(list(r2_no_qtaim.values())))

# mae
mae_no_qtaim = {
    "homo": 0.0027692202740849862,
    "lumo": 0.003111041740738191,
    "gap": 0.0038223465479134537,
    "U0": 1.655494097427923,
}

# qtaim

# r2
r2_qtaim = {
    "homo": 0.9619360397388279,
    "lumo": 0.9892091569213962,
    "gap": 0.9829383869770403,
    "U0": 0.9954721338324276,
}
print(np.mean(list(r2_qtaim.values())))

# mae
mae_qtaim = {
    "homo": 0.0030052467910050232,
    "lumo": 0.003448907182444475,
    "gap": 0.004213777081319067,
    "U0": 1.3710287461084236,
}
# Out:
# 0.9839316531347408
# 0.982388929367423

# %%
# intrinsic only
! ls ../../../../data/saved_models/final_set/chemprop/qm9/big_small/
# Out:
# no_qtaim_preds.csv  qtaim_preds.csv

# %%
chemprop_qm9_preds = (
    "../../../../data/saved_models/final_set/chemprop/qm9/big_small/no_qtaim_preds.csv"
)
chemprop_qm9_preds_qtaim = (
    "../../../../data/saved_models/final_set/chemprop/qm9/big_small/qtaim_preds.csv"
)
test_qm9 = "../benchmark_data/qm9_test_large_qtaim.csv"
df_qm9_chemprop_qtaim = pd.read_csv(chemprop_qm9_preds_qtaim)
df_qm9_chemprop = pd.read_csv(chemprop_qm9_preds)
df_qm9 = pd.read_csv(test_qm9)

# %%
qm9_targets = ["homo", "lumo", "gap"]

df_qm9 = df_qm9[qm9_targets]
df_qm9_chemprop = df_qm9_chemprop[qm9_targets]
df_qm9_chemprop_qtaim = df_qm9_chemprop_qtaim[qm9_targets]

# compute mae for each
mae_dict = {}
r2_dict = {}
for key in qm9_targets:
    mae_dict[key] = mean_absolute_error(df_qm9[key], df_qm9_chemprop[key])
    # compute r2
    r2_dict[key] = r2_score(df_qm9[key], df_qm9_chemprop[key])


import matplotlib.pyplot as plt
import seaborn as sns

name_list = ["homo", "lumo", "gap"]
df_qm9[key]
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
    key = name_list[i]
    sns.scatterplot(x=df_qm9[key], y=df_qm9_chemprop[key], ax=ax[i])
    ax[i].set_title(
        "{} (MAE: {:.5f}, $R^2$: {:.3f})".format(
            key,
            mae_dict[key],
            r2_dict[key],
        )
    )
    ax[i].set_xlabel("Predicted(Hartree)")
    ax[i].set_ylabel("True(Hartree)")
    # rotate labels

    # ax[i].set_ylim(-10, 10)
    # ax[i].plot([-10, 10], [-10, 10], color="black", linestyle="--")

fig.suptitle("Best Performance Chemprop(No QTAIM) QM9 OOD")
fig.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

qm9_targets = ["homo", "lumo", "gap"]

df_qm9 = df_qm9[qm9_targets]
df_qm9_chemprop_qtaim = df_qm9_chemprop_qtaim[qm9_targets]

# compute mae for each
mae_dict = {}
r2_dict = {}
for key in qm9_targets:
    mae_dict[key] = mean_absolute_error(df_qm9[key], df_qm9_chemprop_qtaim[key])
    # compute r2
    r2_dict[key] = r2_score(df_qm9[key], df_qm9_chemprop_qtaim[key])


name_list = ["homo", "lumo", "gap"]
df_qm9[key]
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
    key = name_list[i]
    sns.scatterplot(x=df_qm9[key], y=df_qm9_chemprop_qtaim[key], ax=ax[i])
    ax[i].set_title(
        "{} (MAE: {:.5f}, $R^2$: {:.3f})".format(
            key,
            mae_dict[key],
            r2_dict[key],
        )
    )
    ax[i].set_xlabel("Predicted(Hartree)")
    ax[i].set_ylabel("True(Hartree)")
    # ax[i].set_xlim(-10, 10)
    # ax[i].set_ylim(-10, 10)
    # ax[i].plot([-10, 10], [-10, 10], color="black", linestyle="--")

fig.suptitle("Best Performance Chemprop(QTAIM) QM9 OOD")
fig.tight_layout()

# %%
# QM8 OOD
chemprop_qm8_preds = (
    "../../../../data/saved_models/final_set/chemprop/qm8/big_small/no_qtaim_preds.csv"
)
chemprop_qm8_preds_qtaim = (
    "../../../../data/saved_models/final_set/chemprop/qm8/big_small/qtaim_preds.csv"
)
test_qm8 = "../benchmark_data/qm8_test_large_qtaim.csv"
df_qm8_chemprop_qtaim = pd.read_csv(chemprop_qm8_preds_qtaim)
df_qm8_chemprop = pd.read_csv(chemprop_qm8_preds)
df_qm8 = pd.read_csv(test_qm8)

# %%
qm8_targets = ["CC2_E1", "CC2_E2"]
df_qm8 = df_qm8[qm8_targets]
df_qm8_chemprop = df_qm8_chemprop[qm8_targets]
df_qm8_chemprop_qtaim = df_qm8_chemprop_qtaim[qm8_targets]

# compute mae for each
mae_dict = {}
r2_dict = {}
for key in qm8_targets:
    mae_dict[key] = mean_absolute_error(df_qm8[key], df_qm8_chemprop[key])
    # compute r2
    r2_dict[key] = r2_score(df_qm8[key], df_qm8_chemprop[key])


import matplotlib.pyplot as plt
import seaborn as sns

name_list = ["CC2_E1", "CC2_E2"]

fig, ax = plt.subplots(1, 2, figsize=(14, 7))
for i in range(2):
    key = name_list[i]
    sns.scatterplot(x=df_qm8[key], y=df_qm8_chemprop[key], ax=ax[i])
    ax[i].set_title(
        "{} (MAE: {:.5f}, $R^2$: {:.3f})".format(
            key,
            mae_dict[key],
            r2_dict[key],
        )
    )
    ax[i].set_xlabel("Predicted(Hartree)")
    ax[i].set_ylabel("True(Hartree)")
    # ax[i].set_xlim(-10, 10)
    # ax[i].set_ylim(-10, 10)
    # ax[i].plot([-10, 10], [-10, 10], color="black", linestyle="--")

fig.suptitle("Best Performance Chemprop(No QTAIM) QM8 OOD")
fig.tight_layout()

# %%
r2_dict
# Out:
# {'CC2_E1': 0.8550820529082683, 'CC2_E2': 0.6834834086520697}

# %%
mae_dict
# Out:
# {'CC2_E1': 0.012210971879947078, 'CC2_E2': 0.013436429697845458}

# %%
# compute mae for each
mae_dict = {}
r2_dict = {}
for key in qm8_targets:
    mae_dict[key] = mean_absolute_error(df_qm8[key], df_qm8_chemprop_qtaim[key])
    # compute r2
    r2_dict[key] = r2_score(df_qm8[key], df_qm8_chemprop_qtaim[key])


import matplotlib.pyplot as plt
import seaborn as sns

name_list = ["CC2_E1", "CC2_E2"]

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
for i in range(2):
    key = name_list[i]
    sns.scatterplot(x=df_qm8[key], y=df_qm8_chemprop_qtaim[key], ax=ax[i])
    ax[i].set_title(
        "{} (MAE: {:.5f}, $R^2$: {:.3f})".format(
            key,
            mae_dict[key],
            r2_dict[key],
        )
    )
    ax[i].set_xlabel("Predicted(Hartree)")
    ax[i].set_ylabel("True(Hartree)")
    # ax[i].set_xlim(-10, 10)
    # ax[i].set_ylim(-10, 10)
    # ax[i].plot([-10, 10], [-10, 10], color="black", linestyle="--")

fig.suptitle("Best Performance Chemprop(QTAIM) QM8 OOD")
fig.tight_layout()

# %%
# intensive overall dataset train/test

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
# QM8
chemprop_qm8_preds = (
    "../../../../data/saved_models/final_set/chemprop/qm8/noqtaim_preds.csv"
)
chemprop_qm8_preds_qtaim = (
    "../../../../data/saved_models/final_set/chemprop/qm8/qtaim_preds.csv"
)
test_qm8 = "../benchmark_data/qm8_test_chemprop.csv"
df_qm8_chemprop_qtaim = pd.read_csv(chemprop_qm8_preds_qtaim)
df_qm8_chemprop = pd.read_csv(chemprop_qm8_preds)
df_qm8 = pd.read_csv(test_qm8)

# %%
name_list = ["CC2_E1", "CC2_E2"]

mae_dict = {}
r2_dict = {}
for key in name_list:
    mae_dict[key] = mean_absolute_error(df_qm8[key], df_qm8_chemprop[key])
    # compute r2
    r2_dict[key] = r2_score(df_qm8[key], df_qm8_chemprop[key])


fig, ax = plt.subplots(1, 2, figsize=(14, 7))
for i in range(2):
    key = name_list[i]
    sns.scatterplot(x=df_qm8[key], y=df_qm8_chemprop[key], ax=ax[i])
    ax[i].set_title(
        "{} (MAE: {:.5f}, $R^2$: {:.3f})".format(
            key,
            mae_dict[key],
            r2_dict[key],
        )
    )
    ax[i].set_xlabel("Predicted(Hartree)")
    ax[i].set_ylabel("True(Hartree)")
    # ax[i].set_xlim(-10, 10)
    # ax[i].set_ylim(-10, 10)
    # ax[i].plot([-10, 10], [-10, 10], color="black", linestyle="--")

fig.suptitle("Best Performance Chemprop(No QTAIM) QM8")
fig.tight_layout()

# %%
name_list = ["CC2_E1", "CC2_E2"]

mae_dict = {}
r2_dict = {}
for key in name_list:
    mae_dict[key] = mean_absolute_error(df_qm8[key], df_qm8_chemprop_qtaim[key])
    # compute r2
    r2_dict[key] = r2_score(df_qm8[key], df_qm8_chemprop_qtaim[key])


fig, ax = plt.subplots(1, 2, figsize=(14, 7))
for i in range(2):
    key = name_list[i]
    sns.scatterplot(x=df_qm8[key], y=df_qm8_chemprop_qtaim[key], ax=ax[i])
    ax[i].set_title(
        "{} (MAE: {:.5f}, $R^2$: {:.3f})".format(
            key,
            mae_dict[key],
            r2_dict[key],
        )
    )
    ax[i].set_xlabel("Predicted(Hartree)")
    ax[i].set_ylabel("True(Hartree)")
    # ax[i].set_xlim(-10, 10)
    # ax[i].set_ylim(-10, 10)
    # ax[i].plot([-10, 10], [-10, 10], color="black", linestyle="--")

fig.suptitle("Best Performance Chemprop(QTAIM) QM8")
fig.tight_layout()

# %%
# QM9 full eval

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
# QM9
chemprop_qm9_preds = (
    "../../../../data/saved_models/final_set/chemprop/qm9/noqtaim_preds.csv"
)
chemprop_qm9_preds_qtaim = (
    "../../../../data/saved_models/final_set/chemprop/qm9/qtaim_preds.csv"
)
test_qm9 = "../benchmark_data/qm9_test_chemprop.csv"
df_qm9_chemprop_qtaim = pd.read_csv(chemprop_qm9_preds_qtaim)
df_qm9_chemprop = pd.read_csv(chemprop_qm9_preds)
df_qm9 = pd.read_csv(test_qm9)

# %%
qm9_targets = ["homo", "lumo", "gap"]

mae_dict = {}
r2_dict = {}
for key in qm9_targets:
    mae_dict[key] = mean_absolute_error(df_qm9[key], df_qm9_chemprop[key])
    # compute r2
    r2_dict[key] = r2_score(df_qm9[key], df_qm9_chemprop[key])


fig, ax = plt.subplots(1, 3, figsize=(14, 7))
for i in range(3):
    key = qm9_targets[i]
    sns.scatterplot(x=df_qm9[key], y=df_qm9_chemprop[key], ax=ax[i])
    ax[i].set_title(
        "{} (MAE: {:.5f}, $R^2$: {:.3f})".format(
            key,
            mae_dict[key],
            r2_dict[key],
        )
    )
    ax[i].set_xlabel("Predicted(Hartree)")
    ax[i].set_ylabel("True(Hartree)")
    # ax[i].set_xlim(-10, 10)
    # ax[i].set_ylim(-10, 10)
    # ax[i].plot([-10, 10], [-10, 10], color="black", linestyle="--")

fig.suptitle("Best Performance Chemprop(No QTAIM) QM9")
fig.tight_layout()

# %%
qm9_targets = ["homo", "lumo", "gap"]

mae_dict = {}
r2_dict = {}
for key in qm9_targets:
    mae_dict[key] = mean_absolute_error(df_qm9[key], df_qm9_chemprop_qtaim[key])
    # compute r2
    r2_dict[key] = r2_score(df_qm9[key], df_qm9_chemprop_qtaim[key])


fig, ax = plt.subplots(1, 3, figsize=(14, 7))
for i in range(3):
    key = qm9_targets[i]
    sns.scatterplot(x=df_qm9[key], y=df_qm9_chemprop_qtaim[key], ax=ax[i])
    ax[i].set_title(
        "{} (MAE: {:.5f}, $R^2$: {:.3f})".format(
            key,
            mae_dict[key],
            r2_dict[key],
        )
    )
    ax[i].set_xlabel("Predicted(Hartree)")
    ax[i].set_ylabel("True(Hartree)")
    # ax[i].set_xlim(-10, 10)
    # ax[i].set_ylim(-10, 10)
    # ax[i].plot([-10, 10], [-10, 10], color="black", linestyle="--")

fig.suptitle("Best Performance Chemprop(No QTAIM) QM9")
fig.tight_layout()
